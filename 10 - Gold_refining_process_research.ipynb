# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Технологический-процесс" data-toc-modified-id="Технологический-процесс-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Технологический процесс</a></span></li><li><span><a href="#Параметры-этапов" data-toc-modified-id="Параметры-этапов-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Параметры этапов</a></span></li></ul></li><li><span><a href="#Наименование-признаков" data-toc-modified-id="Наименование-признаков-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Наименование признаков</a></span></li><li><span><a href="#1.1.-Импорт-библиотек" data-toc-modified-id="1.1.-Импорт-библиотек-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>1.1. Импорт библиотек</a></span></li><li><span><a href="#1.2.-Чтение-и-изучение-данных" data-toc-modified-id="1.2.-Чтение-и-изучение-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>1.2. Чтение и изучение данных</a></span><ul class="toc-item"><li><span><a href="#1.2.1.-Расчёт-эффективности-обогащения" data-toc-modified-id="1.2.1.-Расчёт-эффективности-обогащения-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>1.2.1. Расчёт эффективности обогащения</a></span></li><li><span><a href="#1.2.2.-Анализ-признаков" data-toc-modified-id="1.2.2.-Анализ-признаков-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>1.2.2. Анализ признаков</a></span></li></ul></li><li><span><a href="#1.3.-Предобработка-данных" data-toc-modified-id="1.3.-Предобработка-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>1.3. Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-этапу" data-toc-modified-id="Вывод-по-этапу-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Вывод по этапу</a></span></li><li><span><a href="#2.1.-Определение-динамики-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="2.1.-Определение-динамики-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>2.1. Определение динамики концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#2.2.-Анализ-размера-гранул-на-обучающей-и-тестовой-выборках" data-toc-modified-id="2.2.-Анализ-размера-гранул-на-обучающей-и-тестовой-выборках-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>2.2. Анализ размера гранул на обучающей и тестовой выборках</a></span></li><li><span><a href="#2.3.-Анализ-суммарной-концентрации-всех-металлов-на-разных-стадиях" data-toc-modified-id="2.3.-Анализ-суммарной-концентрации-всех-металлов-на-разных-стадиях-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>2.3. Анализ суммарной концентрации всех металлов на разных стадиях</a></span></li><li><span><a href="#Вывод-по-этапу" data-toc-modified-id="Вывод-по-этапу-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Вывод по этапу</a></span></li></ul></li><li><span><a href="#3.1.-Функция-для-расчета-sMAPE" data-toc-modified-id="3.1.-Функция-для-расчета-sMAPE-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>3.1. Функция для расчета sMAPE</a></span></li><li><span><a href="#3.2.-Обучение-и-сравнение-моделей" data-toc-modified-id="3.2.-Обучение-и-сравнение-моделей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>3.2. Обучение и сравнение моделей</a></span></li><li><span><a href="#3.3.-Проверка-моделей-на-тестовой-выборке" data-toc-modified-id="3.3.-Проверка-моделей-на-тестовой-выборке-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>3.3. Проверка моделей на тестовой выборке</a></span></li><li><span><a href="#3.4.-Проверка-модели-на-адекватность" data-toc-modified-id="3.4.-Проверка-модели-на-адекватность-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>3.4. Проверка модели на адекватность</a></span></li><li><span><a href="#Вывод-по-этапу" data-toc-modified-id="Вывод-по-этапу-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Вывод по этапу</a></span></li></ul></div>

# %% [markdown]
# # Сборный проект №2
#
# Данные находятся в трёх файлах:
# •	gold_recovery_train_new.csv — обучающая выборка;
# •	gold_recovery_test_new.csv — тестовая выборка;
# •	gold_recovery_full_new.csv — исходные данные.
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
# В вашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, проверьте по нашей инструкции их на корректность.

# %% [markdown]
# # Описание данных
#
# ### Технологический процесс
# •	Rougher feed — исходное сырье
# •	Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#        -	Xanthate **— ксантогенат (промотер, или активатор флотации);
#        -	Sulphate — сульфат (на данном производстве сульфид натрия);
#        -	Depressant — депрессант (силикат натрия).
# •	Rougher process (англ. «грубый процесс») — флотация
# •	Rougher tails — отвальные хвосты
# •	Float banks — флотационная установка
# •	Cleaner process — очистка
# •	Rougher Au — черновой концентрат золота
# •	Final Au — финальный концентрат золота
#
# ### Параметры этапов
# •	air amount — объём воздуха
# •	fluid levels — уровень жидкости
# •	feed size — размер гранул сырья
# •	feed rate — скорость подачи

# %% [markdown]
# ## Наименование признаков
#
# Наименование признаков должно быть такое: [этап].[тип_параметра].[название_параметра]
# Пример: rougher.input.feed_ag
# Возможные значения для блока [этап]:
# •	rougher — флотация
# •	primary_cleaner — первичная очистка
# •	secondary_cleaner — вторичная очистка
# •	final — финальные характеристики
# Возможные значения для блока [тип_параметра]:
# •	input — параметры сырья
# •	output — параметры продукта
# •	state — параметры, характеризующие текущее состояние этапа
# •	calculation — расчётные характеристики

# %% [markdown]
# # 1. Подготовка данных к анализу

# %% [markdown]
# ## 1.1. Импорт библиотек

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')

from IPython.display import display, HTML, Image
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', -1)

from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score, make_scorer
from sklearn.model_selection import cross_val_score, KFold, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor

import warnings
warnings.filterwarnings('ignore')
# Out:
# /tmp/ipykernel_68/2423543533.py:9: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## 1.2. Чтение и изучение данных

# %%
import os

pth1_0 = 'D:/YANDEX.PRAKTIKUM/DATA_SCIENCE/Сборный_проект_№2/gold_recovery_full_new.csv'
pth1_1 = 'D:/YANDEX.PRAKTIKUM/DATA_SCIENCE/Сборный_проект_№2/gold_recovery_test_new.csv'
pth1_2 = 'D:/YANDEX.PRAKTIKUM/DATA_SCIENCE/Сборный_проект_№2/gold_recovery_train_new.csv'
pth2_0 = '/datasets/gold_recovery_full_new.csv'
pth2_1 = '/datasets/gold_recovery_test_new.csv'
pth2_2 = '/datasets/gold_recovery_train_new.csv'

if (os.path.exists(pth1_0) and os.path.exists(pth1_1) and os.path.exists(pth1_2)):
    full_data = pd.read_csv(pth1_0)
    test_data = pd.read_csv(pth1_1)
    train_data = pd.read_csv(pth1_2)
elif (os.path.exists(pth2_0) and os.path.exists(pth2_1) and os.path.exists(pth2_2)):
    full_data = pd.read_csv(pth2_0)
    test_data = pd.read_csv(pth2_1)
    train_data = pd.read_csv(pth2_2)
else:
    print('Something is wrong')

datasets = {'Исходные данные': full_data, 
            'Обучающая выборка': train_data, 
            'Тестовая выборка': test_data}

# %% [markdown]
# Выведем на экран размер выборок.

# %%
for key, value in datasets.items():
    print(key + ':', value.shape)
# Out:
# Исходные данные: (19439, 87)
# Обучающая выборка: (14149, 87)
# Тестовая выборка: (5290, 53)

# %% [markdown]
# Посмотрим, за какой период доступны данные.

# %%
print('Данные доступны за период от', pd.to_datetime(full_data['date'].min()), 'до', pd.to_datetime(full_data['date'].max()))
# Out:
# Данные доступны за период от 2016-01-15 00:00:00 до 2018-08-18 10:59:59

# %% [markdown]
# Ознакомимся с данными

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# Выведем на экран первые и последние 5 строк исходных данных.

# %%
full_data.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00  6.055403
# 1  2016-01-15 01:00:00  6.029369
# 2  2016-01-15 02:00:00  6.055926
# 3  2016-01-15 03:00:00  6.047977
# 4  2016-01-15 04:00:00  6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0  9.889648                     5.507324
# 1  9.968944                     5.257781
# 2  10.213995                    5.383759
# 3  9.977019                     4.858634
# 4  10.142511                    4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0  42.192020                    70.541216              10.411962
# 1  42.701629                    69.266198              10.462676
# 2  42.657501                    68.116445              10.507046
# 3  42.689819                    68.347543              10.422762
# 4  42.774141                    66.927016              10.360302
#
# ...

# %%
full_data.tail()
# Out:
#                       date  final.output.concentrate_ag  \
# 19434  2018-08-18 06:59:59  3.224920
# 19435  2018-08-18 07:59:59  3.195978
# 19436  2018-08-18 08:59:59  3.109998
# 19437  2018-08-18 09:59:59  3.367241
# 19438  2018-08-18 10:59:59  3.598375
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 19434  11.356233                    6.803482
# 19435  11.349355                    6.862249
# 19436  11.434366                    6.886013
# 19437  11.625587                    6.799433
# 19438  11.737832                    6.717509
#
#        final.output.concentrate_au  final.output.recovery  \
# 19434  46.713954                    73.755150
# 19435  46.866780                    69.049291
# 19436  46.795691                    67.002189
# 19437  46.408188                    65.523246
# 19438  46.299438                    70.281454
#
#        final.output.tail_ag  final.output.tail_pb  final.output.tail_sol  \
# ...

# %% [markdown]
# В отношении датасета full_data можно отметить, что:
#
#      датасет с исходными данными содержит 87 признака и 19 439 объектов;
#      датасет содержит 1 категориальный признак (date) и 86 количественных признаков, тип данных для признака date необходимо  заменить на datetime.

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %% [markdown]
# В отношении датасета train_data можно отметить, что:
#
#      датасет с исходными данными содержит 87 признака и 14 149 объектов;
#      датасет содержит 1 категориальный признак (date) и 86 количественных признаков, тип данных для признака date необходимо  заменить на datetime.

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %% [markdown]
# В отношении датасета test_data можно отметить, что:
#
#      датасет с исходными данными содержит 53 признака и 5 290 объектов;
#      датасет содержит 1 категориальный признак (date) и 52 количественных признаков, тип данных для признака date необходимо  заменить на datetime.

# %% [markdown]
# ### 1.2.1. Расчёт эффективности обогащения

# %% [markdown]
# В соответствии с условиями задачи проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака rougher.output.recovery. Найдем MAE между сделанными расчётами и значением признака.

# %% [markdown]
# В рамках подготовки данных нам необходимо проверить формулу вычисления эффективности обогащения. Формула выглядит так:
#
# recovery = ((C * (F - T)) / (F * (C - T))) * 100%
#
# где:
#
#     C — доля золота в концентрате после флотации/очистки;
#     F — доля золота в сырье/концентрате до флотации/очистки;
#     T — доля золота в отвальных хвостах после флотации/очистки.

# %% [markdown]
# Проверим, правильно ли она рассчитана на примере признака rougher.output.recovery.

# %% [markdown]
# Выведем на экран все столбцы, названия которых содержит слово rougher:

# %%
train_temporary = train_data.copy(deep=True)

# %%
[col for col in train_temporary.columns if 'rougher' in col]
# Out:
# ['rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.input.feed_ag',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.input.feed_sol',
#  'rougher.input.feed_au',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.input.floatbank11_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.recovery',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_pb',
#  'rougher.output.tail_sol',
#  'rougher.output.tail_au',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level',
#  'rougher.state.floatbank10_b_air',
#  'rougher.state.floatbank10_b_level',
# ...

# %% [markdown]
# Для расчета Recovery будем использовать следующие признаки:
#
#     C — rougher.output.concentrate_au
#     F — rougher.input.feed_au
#     T — rougher.output.tail_au.

# %% [markdown]
# Результат расчета формулы будут хранится в признаке rougher.output.recovery.

# %%
C = train_temporary['rougher.output.concentrate_au']
F = train_temporary['rougher.input.feed_au']
T = train_temporary['rougher.output.tail_au']

train_temporary['rougher.output.recovery.checked'] = (C * (F - T)) / (F * (C - T)) * 100
train_temporary['rougher.output.recovery.checked'].head(3)
# Out:
# 0    87.107763
# 1    86.843261
# 2    86.842308
# Name: rougher.output.recovery.checked, dtype: float64

# %% [markdown]
# Проведем расчет метрики MAE между результатом проделанного расчета и значением признака rougher.output.recovery. Для этого перед  расчетом необходимо удалить пропуски из копии датасета train_data.

# %%
train_temporary.dropna(inplace=True)
print('MAE:', 
      mean_absolute_error(train_temporary['rougher.output.recovery'], 
                          train_temporary['rougher.output.recovery.checked']))
# Out:
# MAE: 9.82970122149377e-15

# %% [markdown]
# Вычисленный показатель метрики MAE оказался очень низкий. Это означает, что эффективность обогащения рассчитана правильно.

# %% [markdown]
# ### 1.2.2. Анализ признаков

# %% [markdown]
# В соответствии с условиями задачи проанализируем признаки, недоступные в тестовой выборке: какие это параметры, к какому типу относятся.

# %% [markdown]
# На предыдущем этапе было отмечено, что тестовая выборка содержит значительно меньше признаков, нежели обучающая выборка. Выясним, какие из признаков доступные в обучающей выборке, недоступны в тестовой.

# %%
print('Количество признаков, которые недоступны в тестовой выборке:' , len(set(train_data) - set(test_data)))
set(train_data) - set(test_data)
# Out:
# Количество признаков, которые недоступны в тестовой выборке: 34
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
# ...

# %% [markdown]
# Можно сделать вывод, что в тестовой выборке недоступны признаки из блоков output (параметры продукта) и calculation (расчётные характеристики). Также в тестовой выборке отсутствуют целевые признаки:
#
#     rougher.output.recovery — эффективность обогащения чернового концентрата
#
#     final.output.recovery — эффективность обогащения финального концентрата
#
# Эти параметри в тестовой выборке недоступны, так как замеряются или рассчитываются значительно позже.
#
# Тип данных отсутствующих признаков: float64.

# %% [markdown]
# ## 1.3. Предобработка данных

# %% [markdown]
# На этом этапе проекта:
#
#     - создадим копии датасетов
#     - в копии каждого датафрейма для признака date произведем замену типа данных на datetime
#     - проведем обработку пропусков
#     - далее из копии обучающей выборки удалим признаки, которых нету в тестовой выборке
#     - построим матрицу корреляций и удалим те признаки, которые будут сильно коррелировать с целевыми признаками.

# %% [markdown]
# Создадим копии датасетов.

# %%
full_copy = full_data.copy(deep=True)
train_copy = train_data.copy(deep=True)
test_copy = test_data.copy(deep=True)

datasets_copy = {'Исходные данные': full_copy, 
                 'Обучающая выборка': train_copy, 
                 'Тестовая выборка': test_copy}

# %%
#проверка
for key, value in datasets_copy.items():
    print(key + ':', value.shape)
# Out:
# Исходные данные: (19439, 87)
# Обучающая выборка: (14149, 87)
# Тестовая выборка: (5290, 53)

# %% [markdown]
# Проведем замену типа данных для признака date.

# %%
for key, value in datasets_copy.items():
    value['date'] = pd.to_datetime(value['date'])
    print(value['date'].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]
# datetime64[ns]

# %% [markdown]
# Проведем обработку пропусков:
#
#     - добавим в тестовую выборку целевые признаки
#     - из целевых признаков удалим строки с пропусками
#     - для остальных признаков применим метод ffill и заполним пропуски с предыдущим значением строки.

# %%
test_copy = test_copy.merge(full_copy[['date', 'rougher.output.recovery', 'final.output.recovery']], 
                           how = 'left', on = 'date')
test_copy.shape
# Out:
# (5290, 55)

# %% [markdown]
# Далее удалим строки с пропусками из целевых признаков.

# %%
cols = ['rougher.output.recovery', 'final.output.recovery']

full_copy.dropna(subset=cols, inplace=True)
train_copy.dropna(subset=cols, inplace=True)
test_copy.dropna(subset=cols, inplace=True)

# %% [markdown]
# Заполним пропуски в остальных признаках.

# %%
for key, value in datasets_copy.items():
    value.ffill(inplace=True)
    print(value.isnull().values.any())
# Out:
# False
# False
# False

# %% [markdown]
# Проведем удаление тех признаков, которых нету в тестовой выборке из копии обучающей выборки.

# %% [markdown]
# В обучающей и в тестовой выборках должны остаться только те признаки, которые будем использовать при обучении модели (при условии, что эти признаки не коррелируют с целевыми признаками).

# %%
useful_cols = list(test_copy.columns)
train_copy = train_copy[useful_cols]

# %% [markdown]
# Проверм, что обучающая и тестовая выборки содержат одинаковое количество признаков.

# %%
print('Размер выборки train_copy:', train_copy.shape)
print('Размер выборки test_copy:', test_copy.shape)
# Out:
# Размер выборки train_copy: (14149, 55)
# Размер выборки test_copy: (5290, 55)

# %% [markdown]
# Построим матрицу корреляций и проверим наличие признаков, которые сильно коррелируют с целевыми признаками. Зададим порог: уберем те признаки, где корреляция будет больше 0.5 и -0.5.

# %% [markdown]
# Напишем функцию, которая выделит те строки, где корреляция между признаками будет выше 0.5 или ниже -0.5.

# %%
def highlight(val):
    color = 'red' if val < -0.5 else 'white'
    color = 'lightgreen' if val > 0.5 else 'white'
    return 'background-color: %s' % color

# %% [markdown]
# Построим матрицу корреляций.

# %%
correlation_map = train_copy.corr()
correlation_map[cols].style.applymap(highlight)
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# Таким образом видим, что целевые признаки коррелирует только сами с собой. Обучать модель будем на всех признаках датафрейма train_copy.

# %% [markdown]
# ### Вывод по этапу

# %% [markdown]
# На этом этапе проекта:
#
#     - провели загрузку загрузили и изучили данные. Для каждого из датасетов подготовили EDA отчёт;
#     - провели проверку корреткности расчета эффективность обогащения;
#     - провели анализ признаков недоступных в тестовой выборке
#     - провели предобработку данных, в т.ч.:
#         - обработали пропуски
#         - заменили тип данных для признака date
#         - подготовили обучающую и тестовую выборки для дальнейшей работы: оставили в обоих выборках одинаковое количество признаков и убедились, что они не коррелируют с целевыми признаками.

# %% [markdown]
# # 2. Анализ данных

# %% [markdown]
# ### 2.1. Определение динамики концентрации металлов (Au, Ag, Pb) на различных этапах очистки

# %% [markdown]
# В соответствии с условиями задачи проанализируем, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.

# %% [markdown]
# Из копии датасета с исходными данными отберем признаки, которые характеризуют концентрацию металлов (Au, Ag, Pb) на различных этапах очистки.

# %%
elements = {'золото': 'au', 'серебро': 'ag', 'свинец': 'pb'}
elements
# Out:
# {'золото': 'au', 'серебро': 'ag', 'свинец': 'pb'}

# %% [markdown]
# Создадим функцию для визуализации концентрации металлов (Au, Ag, Pb) на различных этапах очистки.

# %%
def concentrate_visualization(e):
    cols = ['rougher.input.feed_'+e, 'rougher.output.concentrate_'+e, 
            'primary_cleaner.output.concentrate_'+e, 'final.output.concentrate_'+e]
    
    concentrate = full_copy[cols]    
    
    sns.displot(full_copy[cols], 
            legend=True, 
            kde=True, 
            height=7.7, 
            aspect=1.5)
    
    plt.title('Концентрация металла ' + str(e).title() + ' на различных этапах очистки', fontsize=16)
    
    plt.figure(figsize=(12.8,8))
    plt.xticks(rotation=0)
    sns.boxplot(data=full_copy[cols])

# %%
concentrate_visualization(elements['золото'])

# %% [markdown]
# Из графиков можно сделать вывод, что концентрация золота с каждым этапом очистки увеличивается. Наименьшая концентрация золота на этапе rougher.input.feed_au (сырье), самый высокий показатель на этапе final.output.concentrate_au, т.е., после того, как концентрат прошел все стадии очистки.

# %% [markdown]
# По длинным хвостам графиков мы можем сделать вывод о том, что в данных на всех этапах очистки присутствуют выбросы.

# %% [markdown]
# Проанализирауем концентрацию серебра.

# %%
concentrate_visualization(elements['серебро'])

# %% [markdown]
# Из графиков можно сделать вывод что концентрация серебра с каждым этапом очистки уменьшается, а на финальном этапе показатель концентрации серебра даже ниже, чем на первом этапе очистки. Максимальная концентрация серебра достигается после второго этапа очистки. В данных присутствуют выбросы.

# %% [markdown]
# Проанализирауем концентрацию свинца.

# %%
concentrate_visualization(elements['свинец'])

# %% [markdown]
# Из графиков можно сделать вывод о том, что концентрация свинца постепенно растет на первых трех этапах очистки. Меньше всего свинца в начале процесса, когда он входит в состав смеси золотосодержащей руды. На последних 2-х этапах показатель медианы почти совпадает, но при этом на финальной стадии уменьшается разброс значений.

# %% [markdown]
# В данных есть выбросы.

# %% [markdown]
# ### 2.2. Анализ размера гранул на обучающей и тестовой выборках

# %% [markdown]
# В соответствии с условиями задачи сравним распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %% [markdown]
# Для сравнения распределения размеров гранул сырья на обучающей и тестовой выборках необходимо:
#
#     - методом describe() проанализировать статистические данные признаков primary_cleaner.input.feed_size и rougher.input.feed_size на обучающей и тестовой выборках
#     - построить график распределения размеров гранул сырья на обучающей и тестовой выборках.

# %%
rougher_input_feed_size = pd.concat([train_copy['rougher.input.feed_size'], 
                                     test_copy['rougher.input.feed_size']], axis=1) 
rougher_input_feed_size.columns = ['train', 'test']
rougher_input_feed_size.describe()
# Out:
#               train         test
# count  14149.000000  5289.000000
# mean   60.239856     55.951097
# std    23.005310     19.081758
# min    9.659576      0.046369
# 25%    48.966751     43.906347
# 50%    55.269784     50.841029
# 75%    66.007526     62.431047
# max    484.967466    392.494040

# %%
sns.displot(rougher_input_feed_size, legend=True, kde=True, height=6, aspect=1.5)
plt.title('Распределение размеров гранул сырья на обучающей и тестовой выборках (сырье)', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Распределение размеров гранул сырья на обучающей и тестовой выборках (сырье)')

# %%
primary_cleaner_input_feed_size = pd.concat([train_copy['primary_cleaner.input.feed_size'], 
                                     test_copy['primary_cleaner.input.feed_size']], axis=1) 
primary_cleaner_input_feed_size.columns = ['train', 'test']
primary_cleaner_input_feed_size.describe()
# Out:
#               train         test
# count  14149.000000  5290.000000
# mean   7.322310      7.266339
# std    0.614062      0.610219
# min    1.080000      5.650000
# 25%    6.960000      6.890000
# 50%    7.290000      7.250000
# 75%    7.700000      7.600000
# max    10.470000     15.500000

# %%
sns.displot(primary_cleaner_input_feed_size, legend=True, kde=True, height=6, aspect=1.5)
plt.title('Распределение размеров гранул сырья на обучающей и тестовой выборках (первичная очистка)', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Распределение размеров гранул сырья на обучающей и тестовой выборках (первичная очистка)')

# %% [markdown]
# Из графиков можно сделать вывод, что в обоих случаях размеры гранул примерно одинаково распределены на обучающей и тестовой выборках. Можно сделать предположение, что незначительные имеющиеся различия,не будут негативно влиять на работу модели.

# %% [markdown]
# ### 2.3. Анализ суммарной концентрации всех металлов на разных стадиях

# %% [markdown]
# В соответствии с условиями задачи исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах. При обнаружении анломальных значений в суммарном распределении примем решение о возможности их удаления.

# %% [markdown]
# Из датафрейма full_copy отберем те признаки, которые характеризуют концентрацию веществ (Au, Ag, Pb) на разных стадиях и посчитаем общую концентрацию всех металлов для каждой стадии.

# %%
first = 'rougher.input.feed_'
second = 'rougher.output.concentrate_'
third = 'primary_cleaner.output.concentrate_'
fourth = 'final.output.concentrate_'

#full_copy['сырье'] = full_copy[[first+'au', first+'ag', first+'pb']].sum(axis=1)
#full_copy['черновой концентрат'] = full_copy[[second+'au', second+'ag', second+'pb']].sum(axis=1)
#full_copy['концентрат после очистки'] = full_copy[[third+'au', third+'ag', third+'pb']].sum(axis=1)
#full_copy['финальный концентрат'] = full_copy[[fourth+'au', fourth+'ag', fourth+'pb']].sum(axis=1)

full_copy['сырье'] = full_copy[[first+'au', first+'ag', first+'pb', first+'sol']].sum(axis=1)
full_copy['черновой концентрат'] = full_copy[[second+'au', second+'ag', second+'pb', second+'sol']].sum(axis=1)
full_copy['концентрат после очистки'] = full_copy[[third+'au', third+'ag', third+'pb', third+'sol']].sum(axis=1)
full_copy['финальный концентрат'] = full_copy[[fourth+'au', fourth+'ag', fourth+'pb', fourth+'sol']].sum(axis=1)

# %% [markdown]
# Посмотрим и проанализируем общие характеристики полученных столбцов.

# %%
full_copy[['сырье', 'черновой концентрат', 'концентрат после очистки', 'финальный концентрат']].describe()
# Out:
#               сырье  черновой концентрат  концентрат после очистки  \
# count  19439.000000  19439.000000         19439.000000
# mean   57.320789     68.170865            60.764731
# std    7.212680      12.491279            10.017271
# min    0.040000      0.000000             0.000000
# 25%    53.557679     66.012495            58.929364
# 50%    57.594391     70.181495            62.497674
# 75%    61.953459     74.356904            65.667336
# max    76.978947     88.140119            80.749343
#
#        финальный концентрат
# count  19439.000000
# mean   68.653624
# std    7.427536
# min    0.000000
# 25%    67.932362
# 50%    69.598444
# 75%    71.368472
# max    80.210644

# %% [markdown]
# Дополнительно построим графики распределения.

# %%
cols_all = ['сырье', 'черновой концентрат', 'концентрат после очистки', 'финальный концентрат']
    
concentrate = full_copy[cols_all]    
    
sns.displot(full_copy[cols_all], 
            legend=True, 
            kde=True, 
            height=7, 
            aspect=1.5)
    
plt.title('Суммарная концентрация всех металлов на разных стадиях', fontsize=16)
    
plt.figure(figsize=(12.8,8))
plt.xticks(rotation=0)
sns.boxplot(data=full_copy[cols_all])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из анализа графиков можно сделать вывод, что в данных на всех стадиях очистки присутствуют выбросы. Во избежание негативного эффекта влияния на работу будущих моделей они подлежат удалению.

# %% [markdown]
# Также из анализа информации можно сделать вывод, что для некоторых объектов суммарное концентрация всех металлов на этапах черновой концентрат, концентрат после очистки и финальный концентрат составляет 0. Такие объекты также подлежат удалению, так как они также могут негативно повлиять на работу модели.

# %% [markdown]
# Проверим, сколько объектов, где суммарная концентрация металлом равна 0 и сколько таких, где меньше 1.

# %%
for col in cols_all:
    print(col, 'zeros:', len(full_copy[full_copy[col] == 0]))
    print(col, 'under 1:', len(full_copy[full_copy[col] < 1]))
    print('\n')
# Out:
# сырье zeros: 0
# сырье under 1: 5
#
#
# черновой концентрат zeros: 394
# черновой концентрат under 1: 399
#
#
# концентрат после очистки zeros: 108
# концентрат после очистки under 1: 228
#
#
# финальный концентрат zeros: 98
# финальный концентрат under 1: 99

# %% [markdown]
# Проведем обновление исходных данных и оставим там только те объекты, где суммарная концентрация металлом не меньше 1.

# %%
full_clean = full_copy[
    (full_copy['сырье'] >  1) & 
    (full_copy['черновой концентрат'] > 1) & 
    (full_copy['концентрат после очистки'] > 1) & 
    (full_copy['финальный концентрат'] > 1)
]

full_clean.shape
# Out:
# (18722, 91)

# %% [markdown]
# Проверка результата.

# %%
sns.displot(full_clean[['сырье', 'черновой концентрат', 
                       'концентрат после очистки', 'финальный концентрат']], 
            legend=True, 
            kde=True, 
            height=6, 
            aspect=1.5)
plt.title('Суммарная концентрация всех металлов на разных стадиях (обновленный датасет)', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Суммарная концентрация всех металлов на разных стадиях (обновленный датасет)')

# %%
full_clean[['сырье', 'черновой концентрат', 'концентрат после очистки', 'финальный концентрат']].describe()
# Out:
#               сырье  черновой концентрат  концентрат после очистки  \
# count  18722.000000  18722.000000         18722.000000
# mean   57.350936     69.633481            61.467680
# std    7.089930      7.651370             7.445848
# min    8.072476      2.016647             1.083422
# 25%    53.552246     66.389891            59.094492
# 50%    57.600880     70.345534            62.533581
# 75%    61.956159     74.460165            65.658261
# max    76.978947     88.140119            80.749343
#
#        финальный концентрат
# count  18722.000000
# mean   69.035859
# std    5.458724
# min    1.976540
# 25%    67.946259
# 50%    69.609421
# 75%    71.388643
# max    80.210644

# %% [markdown]
# Таким образом, по результатам проведенной работы видно, на всех стадиях минимальный показатель суммарной концентрации всех металлов выше 1, аномалий больше нет. Такой подход позволил уменьшить разброс данных, о чем свидетельствует сравнительно низкие показатели стандартного отклонения (std).

# %% [markdown]
# Перед обучением модели для того, чтобы не искажать ее работу, удалим из обучающего и тестового датасета те объекты, которые мы только что были удалены из датасета full_clear.

# %% [markdown]
# Объекты, которые необходимо удалить, можно отобрать по признаку date.

# %%
train_clean = train_copy[train_copy['date'].isin(full_clean['date'])]
test_clean = test_copy[test_copy['date'].isin(full_clean['date'])]

train_clean.dropna(inplace=True) # удаляем пропуски
test_clean.dropna(inplace=True)  # удаляем пропуски

print('Обучающая выборка', train_clean.shape)
print('Тестовая выборка', test_clean.shape)
# Out:
# Обучающая выборка (13599, 55)
# Тестовая выборка (5074, 55)

# %% [markdown]
# ### Вывод по этапу

# %% [markdown]
# На этом этапе проекта:
#
#     - была проведена проверка, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки;
#
#     Сделали вывод о том, что концентрация каждого из металлов меняется в зависимости от этапа очистки. Так, например, концентрация золота постепенно увеличивается с каждым этапом, а серебра — падает на каждом этапе, свинца - на первых трех этапах растет, а потом стабилизируется. В финальном концентрате медианный показатель концентрации свинца почти такой же, как на предыдущем шаге, но при этом на финальной стадии гораздо ниже показатель разброса значений.
#     При этомна всех этапах очистки в данных присутствуют выбросы.
#
#     - был проведен анализ размера гранул на обучающей и тестовой выборках и был сделан вывод о том, что размеры гранул примерно одинаково распределены в обоих выборках.
#
#     - был проведен проведен анализ суммарной концентрации всех металлов на разных стадиях, были обнаружены и удалены аномалии из всех датасетов.

# %% [markdown]
# # 3. Модель

# %% [markdown]
# ## 3.1. Функция для расчета sMAPE

# %% [markdown]
# В соответствии с условиями задачи запишем функцию для вычисления итоговой sMAPE

# %%
def smape(target, predictions):
    numerator = abs(predictions - target)
    denominator = (abs(target) + abs(predictions)) / 2
    summa = (numerator / denominator).sum()

    smape = 1 / len(target) * summa * 100
    return smape

# %% [markdown]
# Напишем функцию для расчета sMAPE final.

# %%
def smape_final(smape_rougher, smape_final):
    smape_final = 0.25 * smape_rougher + 0.75 * smape_final
    return smape_final

# %% [markdown]
# ## 3.2. Обучение и сравнение моделей

# %% [markdown]
# В соответствии с условиями задачи обучим разные модели и оценим их качество кросс-валидацией. Выберем лучшую модель и проверим её на тестовой выборке.

# %% [markdown]
# Сохраним признаки и целевые признаки в отдельные переменные.

# %%
# train выборка
target_rougher_train = train_clean['rougher.output.recovery']
target_final_train = train_clean['final.output.recovery']
features_train = train_clean.drop(['date', 'rougher.output.recovery', 'final.output.recovery'], axis=1)

# test выборка
target_rougher_test = test_clean['rougher.output.recovery']
target_final_test = test_clean['final.output.recovery']
features_test = test_clean.drop(['date', 'rougher.output.recovery', 'final.output.recovery'], axis=1)

# %%
print('features_train', features_train.shape)
print('features_test', features_test.shape)
# Out:
# features_train (13599, 52)
# features_test (5074, 52)

# %% [markdown]
# С помощью StandardScaler приведем признаки к одному масштабу.

# %%
numeric = features_train.columns
scaler = StandardScaler()
scaler.fit(features_train[numeric])

features_train[numeric] = scaler.transform(features_train[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])

# %% [markdown]
# Проверка результата.

# %%
features_train.head()
# Out:
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0 -0.176997                       0.374685
# 1 -0.214741                       0.424777
# 2 -0.261429                       0.728995
# 3 -0.301414                       0.730742
# 4 -0.411902                       0.907146
#
#    primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0 -0.128329                         0.283191
# 1 -0.128329                         0.320206
# 2 -0.128329                         0.289864
# 3 -0.128329                         0.304434
# 4 -0.128329                         0.339390
#
#    primary_cleaner.state.floatbank8_a_air  \
# 0 -0.446580
# 1 -0.241312
# 2 -0.043832
# 3 -0.056180
# 4 -0.045516
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0 -0.299203
# 1 -0.355821
# 2 -0.330047
# 3 -0.357151
# 4 -0.301002
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0 -0.428633
# 1 -0.241856
# 2 -0.055691
# 3 -0.053615
# 4 -0.047683
#
# ...

# %% [markdown]
# Оценим качество разных моделей при помощи кросс-валидации.

# %%
random_state = 123
cv = 5

# %%
models = [DecisionTreeRegressor(random_state = random_state), 
          RandomForestRegressor(random_state=random_state), 
          LinearRegression()]

# %%
results_cross_val = []

for model in models: 
    
    scorer = make_scorer(smape, greater_is_better=False) 
    
    cross_val_score_rougher = cross_val_score(model, 
                                              features_train, 
                                              target_rougher_train, 
                                              cv=cv, scoring=scorer).mean()
    cross_val_score_final = cross_val_score(model, 
                                            features_train, 
                                            target_final_train, 
                                            cv=cv, scoring=scorer).mean()

    results_cross_val.append({'model name': model.__class__.__name__, 
                              'cross_val_score_rougher': cross_val_score_rougher, 
                              'cross_val_score_final': cross_val_score_final}) 
              
pd.DataFrame(results_cross_val)
# Out:
#               model name  cross_val_score_rougher  cross_val_score_final
# 0  DecisionTreeRegressor -9.145694                -16.069051
# 1  RandomForestRegressor -6.514873                -9.553096
# 2  LinearRegression      -7.282139                -11.027381

# %% [markdown]
# Наилучший результат показывает модель случайного леса. Подберем гиперпараметри и попробуем улучшить работу модели.

# %%
# %%time 
results = []

for depth in range(1,5):
    
    for estimator in range(10, 21, 5):
        
        model = RandomForestRegressor(random_state=random_state, 
                                       n_estimators=estimator, 
                                       max_depth=depth)
        
        scorer = make_scorer(smape, greater_is_better=False) 
    
        cross_val_score_rougher = cross_val_score(model, features_train, target_rougher_train, cv=cv, scoring=scorer).mean()
        cross_val_score_final = cross_val_score(model, features_train, target_final_train, cv=cv, scoring=scorer).mean()

        smape_final_result = smape_final(cross_val_score_rougher, cross_val_score_final)

        results.append({'model name': model.__class__.__name__, 
                        'Hyperparameters': {'random_state': random_state, 
                                            'n_estimators': estimator, 
                                            'max_depth':depth}, 
                        'smape_final_result': smape_final_result})

pd.DataFrame(results)
# Out:
# CPU times: user 2min 44s, sys: 102 ms, total: 2min 44s
# Wall time: 2min 45s
#                model name  \
# 0   RandomForestRegressor
# 1   RandomForestRegressor
# 2   RandomForestRegressor
# 3   RandomForestRegressor
# 4   RandomForestRegressor
# 5   RandomForestRegressor
# 6   RandomForestRegressor
# 7   RandomForestRegressor
# 8   RandomForestRegressor
# 9   RandomForestRegressor
# 10  RandomForestRegressor
# 11  RandomForestRegressor
#
#                                               Hyperparameters  \
# 0   {'random_state': 123, 'n_estimators': 10, 'max_depth': 1}
# 1   {'random_state': 123, 'n_estimators': 15, 'max_depth': 1}
# 2   {'random_state': 123, 'n_estimators': 20, 'max_depth': 1}
# 3   {'random_state': 123, 'n_estimators': 10, 'max_depth': 2}
# 4   {'random_state': 123, 'n_estimators': 15, 'max_depth': 2}
# 5   {'random_state': 123, 'n_estimators': 20, 'max_depth': 2}
# 6   {'random_state': 123, 'n_estimators': 10, 'max_depth': 3}
# ...

# %% [markdown]
# Таким образом подбор гиперпараметров улучшил работу модели. Протестируем работу модели случайного леса с гиперпараметрами n_estimators = 20 и max_depth = 3 на тестовой выборке.

# %% [markdown]
# ## 3.3. Проверка моделей на тестовой выборке

# %% [markdown]
# Обучим модель случайного леса с гиперпараметрами n_estimators = 20 и max_depth = 3 на тестовой выборке.

# %%
model_final = RandomForestRegressor(random_state=random_state, 
                                       n_estimators=20, 
                                       max_depth=3)

model_final.fit(features_train, target_rougher_train)
predictions_r = model_final.predict(features_test)

model_final.fit(features_train, target_final_train)
predictions_f = model_final.predict(features_test)

# %%
smape_r = smape(target_rougher_test, predictions_r)
smape_f = smape(target_final_test, predictions_f)

print('Итоговое sMAPE:', smape_final(smape_r, smape_f))
# Out:
# Итоговое sMAPE: 7.115152048651341

# %% [markdown]
# ## 3.4. Проверка модели на адекватность

# %% [markdown]
# Для проверки модели на адекватность используем регрессор DummyRegressor из библиотеки Skelarn.

# %%
dummy_regr = DummyRegressor(strategy='mean')

dummy_regr.fit(features_train, target_rougher_train)
predictions_r_dummy = dummy_regr.predict(features_test)

dummy_regr.fit(features_train, target_final_train)
predictions_f_dummy = dummy_regr.predict(features_test)

# %%
smape_r_dummy = smape(target_rougher_test, predictions_r_dummy)
smape_f_dummy = smape(target_final_test, predictions_f_dummy)

print('Итоговое sMAPE', smape_final(smape_r_dummy, smape_f_dummy))
# Out:
# Итоговое sMAPE 7.683947910201315

# %% [markdown]
# Можно сделать вывод, что обученная модель работает немного лучше чем константная модель: ошибка обученной модели составляет 7,04%, константной - 7.68%.
# Для улучшения работы модели возможны сделующие варианты:
#
#     - улучшение исходных данных;
#     - улучшение работу самой модели через более детальный подбор моделей и гиперпараметров;
#     - улучшение качества первичной аналистики бизнес-процессов на основании которых построена модель.

# %% [markdown]
# ## Вывод по этапу

# %% [markdown]
# На этом этапе проекта:
#
#     - создали функции для расчёта sMAPE и итоговой sMAPE
#     - сравнили работу разных моделей (DecisionTreeRegressor (), RandomForestRegressor, LinearRegression);
#     - провели тестирование модель случайного леса с гиперпараметрами n_estimators = 20 и max_depth = 3 на тестовой выборке и проверили модель на адекватность.
#     Сделали вывод, что обученная модель работает лучше чем константная модель: ошибка обученной модели составляет 7,04%, константной - 7.68%.

# %% [markdown]
# # 4. Общий вывод

# %% [markdown]
# Во время проекта были выполнены следующие шаги:
#
# 1) в ходе подготовки и предобработки данных:
#
#     - прочитаны и изучены данные из представленных датасетов
#     - проведена предобработка данных (обработка пропусков, замена типа данных, проверка на дубликаты)
#     - проведен анализ признаков и подготовилены выборки для дальнейшей работы (оставили в обучающей и тестовой выборках одинаковое количество признаков и убедились, что они не коррелируют с целевыми признаками)
#     - проверили корректность расчета эффективности обогащения.
#
# 2) в ходе анализ данных:
#
#     - проведена проверка того, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Можем сделать вывод, что концентрация каждого из металлов меняется в зависимости от этапа очистки: концентрация золота увеличивается с каждым этапом существенно, серебра — падает, а свинца на первых трех этапах, а потом стабилизируется;
#     - проведен  анализ размера гранул на обучающей и тестовой выборках и был сделан вывод, что размеры гранул примерно одинаково распределены в обучающей и тестовой выборках;
#     - проведен  анализ суммарной концентрации всех металлов на разных стадиях, обнаружены и удалены аномалии (большое количество значений меньше 5) из всех датасетов.
#
# 3) в ходе обучения модели:
#
#     - созданы функции для расчёта sMAPE и итоговой sMAPE
#     -  проведено сравнение работы разных моделей (DecisionTreeRegressor, LinearRegression, RandomForestRegressor) в качестве лучшей выбрана модель случайного леса с гиперпараметрами n_estimators = 20 и max_depth = 3. Работа финальной модели протестирована на тестовой выборке, где она показала неплохой результат: ошибка обученной модели составляет 7,04%, константной - 7.68%.
